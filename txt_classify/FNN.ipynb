# %%
import numpy as np
import pandas as pd
import torch
import spacy

# %%
dir_all_data='data\\data.tsv'

#超参数设置
BATCH_SIZE=10
cpu=True
if cpu :
    USE_CUDA = False
    DEVICE = torch.device('cpu')
else:
    USE_CUDA = torch.cuda.is_available()
    DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    torch.cuda.set_device(0)
torch.cuda.is_available()
# Out:
# False

# %%
nlp = spacy.load("en_core_web_sm")

data = pd.read_csv("data\\all_data.tsv",sep='\t')

# 将文本转换为向量
data['vectorized_text'] = data['Phrase'].apply(lambda x: nlp(x).vector)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 6
#       3 data = pd.read_csv("data\\all_data.tsv",sep='\t')
#       5 # 将文本转换为向量
# ----> 6 data['vectorized_text'] = data['Phrase'].apply(lambda x: nlp(x).vector)
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[11], line 6, in <lambda>(x)
#       3 data = pd.read_csv("data\\all_data.tsv",sep='\t')
#       5 # 将文本转换为向量
# ----> 6 data['vectorized_text'] = data['Phrase'].apply(lambda x: nlp(x).vector)
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\spacy\language.py:1052, in Language.__call__(self, text, disable, component_cfg)
#    1050     error_handler = proc.get_error_handler()
#    1051 try:
# -> 1052     doc = proc(doc, **component_cfg.get(name, {}))  # type: ignore[call-arg]
#    1053 except KeyError as e:
#    1054     # This typically happens if a component is not initialized
#    1055     raise ValueError(Errors.E109.format(name=name)) from e
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\spacy\pipeline\trainable_pipe.pyx:52, in spacy.pipeline.trainable_pipe.TrainablePipe.__call__()
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\spacy\pipeline\transition_parser.pyx:264, in spacy.pipeline.transition_parser.Parser.predict()
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\spacy\pipeline\transition_parser.pyx:285, in spacy.pipeline.transition_parser.Parser.greedy_parse()
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\thinc\model.py:334, in Model.predict(self, X)
#     330 def predict(self, X: InT) -> OutT:
#     331     """Call the model's `forward` function with `is_train=False`, and return
#     332     only the output, instead of the `(output, callback)` tuple.
#     333     """
# --> 334     return self._func(self, X, is_train=False)[0]
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\spacy\ml\tb_framework.py:34, in forward(model, X, is_train)
#      33 def forward(model, X, is_train):
# ---> 34     step_model = ParserStepModel(
#      35         X,
#      36         model.layers,
#      37         unseen_classes=model.attrs["unseen_classes"],
#      38         train=is_train,
#      39         has_upper=model.attrs["has_upper"],
#      40     )
#      42     return step_model, step_model.finish_steps
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\spacy\ml\parser_model.pyx:250, in spacy.ml.parser_model.ParserStepModel.__init__()
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\thinc\layers\with_array.py:42, in forward(model, Xseq, is_train)
#      40     return model.layers[0](Xseq, is_train)
#      41 else:
# ---> 42     return cast(Tuple[SeqT, Callable], _list_forward(model, Xseq, is_train))
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\thinc\layers\with_array.py:77, in _list_forward(model, Xs, is_train)
#      75 lengths = NUMPY_OPS.asarray1i([len(seq) for seq in Xs])
#      76 Xf = layer.ops.flatten(Xs, pad=pad)
# ---> 77 Yf, get_dXf = layer(Xf, is_train)
#      79 def backprop(dYs: ListXd) -> ListXd:
#      80     dYf = layer.ops.flatten(dYs, pad=pad)
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\thinc\layers\residual.py:41, in forward(model, X, is_train)
#      38     else:
#      39         return d_output + dX
# ---> 41 Y, backprop_layer = model.layers[0](X, is_train)
#      42 if isinstance(X, list):
#      43     return [X[i] + Y[i] for i in range(len(X))], backprop
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
#     [... skipping similar frames: Model.__call__ at line 310 (1 times)]
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\thinc\layers\chain.py:54, in forward(model, X, is_train)
#      52 callbacks = []
#      53 for layer in model.layers:
# ---> 54     Y, inc_layer_grad = layer(X, is_train=is_train)
#      55     callbacks.append(inc_layer_grad)
#      56     X = Y
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\thinc\model.py:310, in Model.__call__(self, X, is_train)
#     307 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     308     """Call the model's `forward` function, returning the output and a
#     309     callback to compute the gradients via backpropagation."""
# --> 310     return self._func(self, X, is_train=is_train)
#
# File d:\graduation_project\envs\homework_ML\lib\site-packages\thinc\layers\maxout.py:52, in forward(model, X, is_train)
#      50 W = model.get_param("W")
#      51 W = model.ops.reshape2f(W, nO * nP, nI)
# ---> 52 Y = model.ops.gemm(X, W, trans2=True)
#      53 Y += model.ops.reshape1f(b, nO * nP)
#      54 Z = model.ops.reshape3f(Y, Y.shape[0], nO, nP)
#
# KeyboardInterrupt:
